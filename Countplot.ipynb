# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df =pd.read_csv('practice.csv')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
plt.figure(figsize=(4,4))
sns.countplot(x='sex',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
plt.figure(figsize=(4,4))
sns.countplot(x='island',data=df,hue='sex')
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %%
plt.figure(figsize=(4,4))
sns.countplot(x='island',data=df,hue='sex',palette='cool')
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %%
plt.figure(figsize=(4,4))
sns.countplot(x='island',data=df,hue='sex',palette='prism')
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %%
plt.figure(figsize=(4,4))
sns.countplot(x='island',data=df,hue='sex',palette='spring')
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %% [markdown]
# # Box plot

# %%
sns.boxplot(x='body_mass_g',data=df)
# Out:
# <Axes: xlabel='body_mass_g'>

# %%
sns.boxplot(x='body_mass_g',y='flipper_length_mm',data=df,hue='sex')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>
